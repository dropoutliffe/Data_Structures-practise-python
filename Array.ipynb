# %% [markdown]
# <a href="https://colab.research.google.com/github/dropoutliffe/Data_Structures-practise-python/blob/main/Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Array largest numbers

# %%
array = [4,5,2,4,7,23,22,1]

max_val == array[0]
for num in array:
  if num > max_val:
    max_val = num

print("maximum", max_val)
# Out:
# maximum 23

# %%
#reverse the array

arr = [2,5,3,4,6,234,534,6354]
s
left , right = 0, len(arr)-1

while left < right:
  arr[left], arr[right] = arr[right], arr[left]
  left += 1
  right -= 1

print(arr)
# Out:
# [6354, 534, 234, 6, 4, 3, 5, 2]

# %%
#second largest number in the array
