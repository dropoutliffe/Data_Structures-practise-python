# %% [markdown]
# <a href="https://colab.research.google.com/github/dropoutliffe/Data_Structures-practise-python/blob/main/ZeroDay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isEven(n):
  rem = n %2;
  if rem ==0:
    return True
  else:
    return False


if __name__ == "__main__":
  n = 15
  if isEven(n):
    print("true")
  else:
    print("false")
# Out:
# false

# %%
#bitwise operator Approch

def iseven(m):

  if (n & 1)==0:
    return True
  else:
    return False

if __name__ == "__main__":
  m = 12
  if iseven(m):
    print("true")
  else:
    print("false")
# Out:
# true

# %%
def even(n):
  return (n &1 ) == 0

print(even(13))
# Out:
# False
